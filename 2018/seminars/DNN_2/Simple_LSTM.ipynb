# %% [markdown]
# ## Here we will use Long-Short Term Memory RNN.
# ** Original paper (not for the faint of heart): http://www.bioinf.jku.at/publications/older/2604.pdf **
#
# ** Wiki: https://en.wikipedia.org/wiki/Long_short-term_memory **
#
# ** Good blog: https://ayearofai.com/rohan-lenny-3-recurrent-neural-networks-10300100899b**

# %%
import os
import random
import numpy as np
import tensorflow as tf
# Out:
# /home/vprov/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Text.
data = ""
for fname in os.listdir("codex"):
    with open("codex/"+fname, encoding='cp1251') as fin:
        data += fin.read()

# %%
max_len = 40
step = 2
num_units = 128
learning_rate = 0.001
batch_size = 200
epoch = 60
temperature = 0.5

# %%
def featurize(text):
    '''
     featurize the text to train and target dataset
    '''
    unique_chars = list(set(text))
    len_unique_chars = len(unique_chars)

    input_chars = []
    output_char = []

    for i in range(0, len(text) - max_len, step):
        input_chars.append(text[i:i+max_len])
        output_char.append(text[i+max_len])
    print(len(input_chars))
    print(len_unique_chars)
    train_data = np.zeros((len(input_chars), max_len, len_unique_chars))
    target_data = np.zeros((len(input_chars), len_unique_chars))

    for i , each in enumerate(input_chars):
        for j, char in enumerate(each):
            train_data[i, j, unique_chars.index(char)] = 1
        target_data[i, unique_chars.index(output_char[i])] = 1
    return train_data, target_data, unique_chars, len_unique_chars

# %%
def rnn(x, weight, bias, len_unique_chars):
    '''
     define rnn cell and prediction
    '''
    x = tf.transpose(x, [1, 0, 2])
    x = tf.reshape(x, [-1, len_unique_chars])
    x = tf.split(x, max_len, 0)

    cell = tf.contrib.rnn.BasicLSTMCell(num_units, forget_bias=1.0)
    outputs, states = tf.contrib.rnn.static_rnn(cell, x, dtype=tf.float32)
    prediction = tf.matmul(outputs[-1], weight) + bias
    return prediction

# %%
def sample(predicted):
    '''
     helper function to sample an index from a probability array
    '''
    exp_predicted = np.exp(predicted/temperature)
    predicted = exp_predicted / np.sum(exp_predicted)
    probabilities = np.random.multinomial(1, predicted, 1)
    return probabilities

def run(train_data, target_data, unique_chars, len_unique_chars):
    '''
     main run function
    '''
    x = tf.placeholder("float", [None, max_len, len_unique_chars])
    y = tf.placeholder("float", [None, len_unique_chars])
    weight = tf.Variable(tf.random_normal([num_units, len_unique_chars]))
    bias = tf.Variable(tf.random_normal([len_unique_chars]))

    prediction = rnn(x, weight, bias, len_unique_chars)
    softmax = tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y)
    cost = tf.reduce_mean(softmax)
    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

    init_op = tf.global_variables_initializer()
    sess = tf.Session()
    sess.run(init_op)

    num_batches = int(len(train_data)/batch_size)

    for i in range(epoch):
        print("----------- Epoch {0}/{1} -----------".format(i+1, epoch))
        count = 0
        for _ in range(num_batches):
            train_batch, target_batch = train_data[count:count+batch_size], target_data[count:count+batch_size]
            count += batch_size
            sess.run([optimizer] ,feed_dict={x:train_batch, y:target_batch})

        #get on of training set as seed
        seed = train_batch[:1:]

        #to print the seed 40 characters
        seed_chars = ''
        for each in seed[0]:
                seed_chars += unique_chars[np.where(each == max(each))[0][0]]
        print("Seed:", seed_chars)

        #predict next 1000 characters
        for i in range(100):
            if i > 0:
                remove_fist_char = seed[:,1:,:]
                seed = np.append(remove_fist_char, np.reshape(probabilities, [1, 1, len_unique_chars]), axis=1)
            predicted = sess.run([prediction], feed_dict = {x:seed})
            predicted = np.asarray(predicted[0]).astype('float64')[0]
            probabilities = sample(predicted)
            predicted_chars = unique_chars[np.argmax(probabilities)]
            seed_chars += predicted_chars
        print('Result:', seed_chars)
    sess.close()

# %%
# RAM is limited.
train_data, target_data, unique_chars, len_unique_chars = featurize(data[:10 ** 5])

# %%
run(train_data, target_data, unique_chars, len_unique_chars)
# Out:
# WARNING:tensorflow:From <ipython-input-6-68a8de705926>:20: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# ----------- Epoch 1/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие рании  орано оя о лсокооской ссий дерации  осотвтоы оскоостий осто осиой тодрасии ососвокононоы мо
# ----------- Epoch 2/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие сидельноы мо имостовив оонойсиий совостоворий осия омодстовамономы одельнымо совостовоной остовов и
# ----------- Epoch 3/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации  ракотамой стовоновит Российской Федерации о моженамо ю астовоного далином таж
# ----------- Epoch 4/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации номого области ва обрановленомого далостования таствым Российской Федерации о
# ----------- Epoch 5/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации о делажет в Российской Федерации о знаконо Российской Федерации омотовымо огор
# ----------- Epoch 6/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации о даможенным правовы дактов Российской Федерации повляюти и совономотения доло
# ----------- Epoch 7/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации ореговорых Российской Федерации постивания мегу раворание споновым наконодачел
# ----------- Epoch 8/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации о дойствот Российской Федерации тасовых авты и соворовамии станов Российской Ф
# ----------- Epoch 9/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации но собоствении в сомотстватьи законодательством Российской Федерации и торжены
# ----------- Epoch 10/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие совном чесударых в договорожностваенся в послосом чествами ос облазие истования на онным чатовым су
# ----------- Epoch 11/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие собщест вние менстватем устаровленное нели стотоветь 2. а прномо чесли межет унороданованиства Росс
# ----------- Epoch 12/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации ов остовотсив и станов ине правовые сконых пророворова Российской Федерации и
# ----------- Epoch 13/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие соботренном и государственном власти Российской Федерации и области и собоженное таков о таком.
#
#  С
# ----------- Epoch 14/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие собода отномочий когостиции ов доможенностью собществуются в полеститений собрых предека остановани
# ----------- Epoch 15/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие полномоченного волостования в Российской Федерации.
#  2. Прездене Российской Федерации и обрасти ств
# ----------- Epoch 16/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и полномочий в сответствии с незбедератив кодей овной стовкой собласти, наконоговых актов Российско
# ----------- Epoch 17/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие савот Федерации и сударовления в Российской Федерации и ображений ставов намо 1. Постановления прав
# ----------- Epoch 18/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие Российской Федерации и органов изборантельством Российской Федерации и догужданов на органовании те
# ----------- Epoch 19/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенного делания.
#  2. ПредударениРоссийской Федерации на осуществляет приняелей собих стотьиской
# ----------- Epoch 20/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а таможеннодатель орущитивание правовые акта в сответствии с законодательством Российской Федерации
# ----------- Epoch 21/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а также норматив содом менениций в статьи 117 Конституции Российской Федерации и в полномочия Прави
# ----------- Epoch 22/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие совста товеронночи полномочной ихранитыринных органов Российской Федерации в полномочия тамжет намо
# ----------- Epoch 23/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и тольствании с законодательством Российской Федерации органы вслосий постовенности, внешения в сво
# ----------- Epoch 24/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенноо дела.
#
#  2. Государственноя Дему оредление таможенногораци
#
#
#  Статья 13
#
#  1. Предударст Р
# ----------- Epoch 25/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенноо дела
#
#
#  Статья 67
#  1. Федеральное монеститсява в унствании и порядок определяется в преч
# ----------- Epoch 26/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие совта советсенностициастая предяты веденного раными и полномочий может налогарование тстов стаь сму
# ----------- Epoch 27/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а тольстно чанов, слога встовании в Российской Федерации ов основлении и навномого сомывенно ранств
# ----------- Epoch 28/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а таможенноодтералиные органов законодательством Российской Федерации и органов осубы.
#
#  2. Констит
# ----------- Epoch 29/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенного зака
#
#  Федеральных прекусов с вопрова и внедит в неченов настоящем Конституции нистрави
# ----------- Epoch 30/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а таможенной дела
#
#   О толковании статьи 117К омстасавки РФ
#  1. Конституции срутых принуеменным пр
# ----------- Epoch 31/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а таможенного зала отот2тствующюна и иные правовые акты Российской Федерации о наком ноститулиное с
# ----------- Epoch 32/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а том состобусти и дойстваятся в полносом чемовения чема в сорутках и веренным и дейнтурых органы и
# ----------- Epoch 33/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие сображенноститруцлий твером человерае и в Российской Федерации и деятельности.
#  2. Нактонным закон
# ----------- Epoch 34/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие каторых приковы и рассмотрению ериней освейнометельной толькрый мистманства донстрольно мене тародн
# ----------- Epoch 35/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а томоженноот дела опресемоет полномочия мо топрессий с федерального закона от 29.01.2004 №58-ФЗ)
#
# ----------- Epoch 36/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие ели оредными по придаем к истарум и после стутьссий аватов, приненым народом.
#
#  Статья 7ре празгани
# ----------- Epoch 37/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а таможенного законодательства и иными правовым акальные должностных доловочностанульнод юриольы вн
# ----------- Epoch 38/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а томитстой пому, его сударствини.
#
#  Статья 9.
#  1. Полозитствою слуци.
# 2. Стако уетаровои, законом
# ----------- Epoch 39/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а таможенной дела в тем.
#
#  2. Совераем Федерации Российской Федерации о вопросовом совератья чареси
# ----------- Epoch 40/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а тамже наторальном договором Российской Федерации на ягланичать приняты и сумернодать вседенна объ
# ----------- Epoch 41/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенногот еразараваютсу депутатов Государственной Думы, також нают поверной растырации Конституц
# ----------- Epoch 42/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенной зеранод теморение о нопровении положения подовирой мысти Российской Федерации от должнос
# ----------- Epoch 43/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а тамже выпольт несену собых снотия.
#
#  Статья 79
#  Конститууции Российской Федерации и федерального
# ----------- Epoch 44/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а толжения по такожеными органы субраттульными положения положения, отвержноют явлюеткымо предусмор
# ----------- Epoch 45/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие а тамже нать принен до жазберод тельности и Государственной Думы, таможенных пелатов, ов осудановле
# ----------- Epoch 46/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и в порядок, их и деятольной области установлению с судение оп2 чаны, чет равите Российской Федерац
# ----------- Epoch 47/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и собраненностаелинных положе с дечтным самосмых аедельства, а танкриет0и Российской Федерации о во
# ----------- Epoch 48/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и собранте равой дитей Российской Федерации, введения в соруженного  осущественных Конституцией Рос
# ----------- Epoch 49/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и принятим в законовать в решение протражельнать зако, судееными и деятельной Российской Федерации
# ----------- Epoch 50/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и принятим вереного не и колопрением.
#  Статья 6ренном дегования тамов намо обномно отрашения просуд
# ----------- Epoch 51/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие установленным законом тель.
#  2. Кажды из подетат и таможенной праложенном правимы в соответстве чес
# ----------- Epoch 52/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие таможенного дла от вожения принявияма таровенной слатирсяваем недетальное мене о толожении правовых
# ----------- Epoch 53/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие у совмановенее объакты, водонстрация.
#  В Российской Федерации вступлени отно человати и насят повес
# ----------- Epoch 54/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и свободые актанки, еет равоство настоящего закона делинуе осмой натитурушения е в органовоченающи
# ----------- Epoch 55/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и принятим веренико немеренся в танованной заседа, том опреняюта и нарове могут подитером судом но
# ----------- Epoch 56/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие  остановании в також.
#
#  Статья 81
#  Конституции Российской Федерации о не моготов осудар введения ст
# ----------- Epoch 57/60 -----------
# Seed:  установлено иное.
#
#  Статья 8.
#  Действие
# Result:  установлено иное.
#
#  Статья 8.
#  Действие и принятии обязычения в тальномнт органиискои, простуютелино знаконодательном толовора и устанами с
# ----------- Epoch 58/60 -----------
